# %%
name="Onwuzurike_Goodness_Kosisochukwu"
print(name)
# Out:
# Onwuzurike_Goodness_Kosisochukwu

# %%
num1=25
num2=10
sum=num1+num2
difference=num1-num2
product=num1*num2
quotient=num1/num2
print(sum, difference, product, quotient)
# Out:
# 35 15 250 2.5

# %%
length=15
width=9
area_of_a_rectangle=length*width
print("area = ", area_of_a_rectangle)
# Out:
# area =  135

# %%
scores=(78, 82, 65, 90,75)
total_score=(78+82+65+75)
average=total_score/5
print('total_scores=', total_score, 'average=', average)
# Out:
# total_scores= 300 average= 60.0

# %%
price=2500
quantity=7
total_cost=price*quantity
print('total=', total_cost)
# Out:
# total= 17500

# %%
remainder=47%6
print('remainder=', remainder)
# Out:
# remainder= 5

# %%
x=5**4
print('result=', x)
# Out:
# result= 625

# %%
product_cost=8500
discount=20/100
discount_amount=product_cost*discount
final_price=product_cost-discount_amount
print(discount_amount, final_price)
# Out:
# 1700.0 6800.0

# %%
total_minutes=156
hours=total_minutes//60
minutes_left=total_minutes%60
print(hours,'hour(s)', minutes_left, 'minute(s)')
# Out:
# 2 hour(s) 36 minute(s)

# %%
distance=240
time=3
speed=distance/time
print(speed, 'km/h')
# Out:
# 80.0 km/h
